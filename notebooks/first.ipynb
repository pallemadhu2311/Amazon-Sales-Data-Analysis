# %% [markdown]
# ## 1. Importing the Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# read in the data
data = pd.read_csv('/Users/smartcookie/Desktop/Data Engineering Files/Projects/Python Projectes/Amazon Sales Data Project/Data/amazon.csv')

data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
data.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
data.tail()
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# ...

# %%
data.sample(10)
# Out:
#       product_id                                       product_name  \
# 788   B08GYG6T12  SanDisk Ultra SDHC UHS-I Card 32GB 120MB/s R f...
# 850   B07SBGFDX9     Pentonic Multicolor Ball Point Pen, Pack of 10
# 50    B07P681N66  TP-Link AC600 600 Mbps WiFi Wireless Network U...
# 269   B09LRZYBH1  KRISONS Thunder Speaker, Multimedia Home Theat...
# 158   B07VSG5SXZ  ZEBRONICS HAA2021 HDMI version 2.1 cable with ...
# 802   B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...
# 1350  B077BTLQ67  Orient Electric Aura Neo Instant 3L Water Heat...
# 948   B08XNL93PL  Portronics Ruffpad 15 Re-Writable LCD Screen 3...
# 846   B09Z7YGV3R  Anjaney Enterprise Smart Multipurpose Foldable...
# 608   B09YV4RG4D  Fire-Boltt Ninja 3 Smartwatch Full Touch 1.69 ...
#
#                                                category discounted_price  \
# 788   Electronics|Accessories|MemoryCards|SecureDigi...             ₹449
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
data.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
data.shape
# Out:
# (1465, 16)

# %% [markdown]
# ## 2. Data Cleaning

# %%
data.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
data.nunique()
# Out:
# product_id             1351
# product_name           1337
# category                211
# discounted_price        550
# actual_price            449
# discount_percentage      92
# rating                   28
# rating_count           1143
# about_product          1293
# user_id                1194
# user_name              1194
# review_id              1194
# review_title           1194
# review_content         1212
# img_link               1412
# product_link           1465
# dtype: int64

# %%
# 1 . Handle Missing Values
# Check for missing values
missing_values = data.isnull().sum()

# %%
print(missing_values)
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
data[['rating','rating_count']] = data[['rating','rating_count']].fillna(0)

# %%
latest_values = data.isnull().sum()
print(latest_values)
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# 3. Remove duplicates
# Check for duplicates

duplicates = data.duplicated().sum()
print(f"No.of Duplicates: {duplicates}")
# Out:
# No.of Duplicates: 0

# %%
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
data[['discounted_price','actual_price','discount_percentage']].describe()
# Out:
#        discounted_price actual_price discount_percentage
# count              1465         1465                1465
# unique              550          449                  92
# top                ₹199         ₹999                 50%
# freq                 53          120                  56

# %%
# Columns to Clean 

cols_to_clean = ['discounted_price','actual_price','discount_percentage','rating_count','rating']

# Remove special characters and convert to numeric
data[cols_to_clean] = data[cols_to_clean].replace({
                                            '₹': '',
                                            '%': '',
                                            ',':''},
                                            regex=True).apply(pd.to_numeric,errors='coerce')

# %%
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# ...

# %%
# Discounted Amount 
data['discounted_amount']  = data['actual_price'] - data['discounted_price']

# %%
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# ...

# %%
data['actual_price'].max()
# Out:
# 139900.0

# %%
data['actual_price'].min()
# Out:
# 39.0

# %%
data['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    181
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.0      4
# 3.1      4
# 5.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# 2.0      1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
data.sort_values(by='rating',ascending=False).head(10)[['product_name','rating','rating_count']]
# Out:
#                                            product_name  rating  rating_count
# 324   REDTECH USB-C to Lightning Cable 3.3FT, [Apple...     5.0             0
# 174   Syncwire LTG to USB Cable for Fast Charging Co...     5.0             5
# 775   Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0            23
# 1145  Swiffer Instant Electric Water Heater Faucet T...     4.8         53803
# 1201  Oratech Coffee Frother electric, milk frother ...     4.8            28
# 1299  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...     4.8          3964
# 249   Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...     4.7          5935
# 1388  Campfire Spring Chef Prolix Instant Portable W...     4.7          2591
# 1226  Zuvexa USB Rechargeable Electric Foam Maker - ...     4.7            54
# 459   Spigen EZ Fit Tempered Glass Screen Protector ...     4.7          7779

# %%
data['category'].value_counts()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Electronics|Cameras&Photography|Accessories|Batteries&Chargers|BatteryChargers                                               1
# ...

# %%
data.groupby('category')['rating'].mean().sort_values(ascending=False).head(10)
# Out:
# category
# Computers&Accessories|Tablets                                               4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters    4.5
# Electronics|Cameras&Photography|Accessories|Film                            4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                          4.5
# Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea&Espresso|CoffeePresses       4.5
# Electronics|PowerAccessories|SurgeProtectors                                4.5
# HomeImprovement|Electrical|CordManagement                                   4.5
# Home&Kitchen|CraftMaterials|PaintingMaterials                               4.5
# Computers&Accessories|Components|Memory                                     4.5
# Name: rating, dtype: float64

# %% [markdown]
# ## 3. Data Visualisation

# %%
# 1. Rating Distribution

sns.histplot(data['rating'], bins=20, kde=True,color='blue', alpha=0.6)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# 2. Price Distribution

sns.histplot(data['actual_price'], bins=20, kde=True,color='green', alpha=0.6)
plt.title('Distribution of Actual Price')
plt.xlabel('Actual Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# 3. Discounted Price Distribution
sns.histplot(data['discounted_price'], bins=20, kde=True,color='red', alpha=0.6)
plt.title('Distribution of Discounted Price')
plt.xlabel('Discounted Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#4. Discount Percentage Distribution
sns.histplot(data['discount_percentage'], bins=20, kde=True,color='purple', alpha=0.6)
plt.title('Distribution of Discount Percentage')
plt.xlabel('Discount Percentage')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Rating Count vs Rating
sns.scatterplot(data=data,x ='rating_count',y='rating',color='black', alpha=0.6)
plt.title('Rating Count vs Rating')
plt.xlabel('Rating Count')
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
# Impact on Discount Percentage on Rating
data["discount_percentage"] = pd.to_numeric(data["discount_percentage"], errors="coerce")
data["rating"] = pd.to_numeric(data["rating"], errors="coerce")
discount_vs_rating = data.groupby("discount_percentage")["rating"].mean().dropna()


sns.lineplot(x=discount_vs_rating.index,y=discount_vs_rating.values,markers='' ,color='red', alpha=0.6)
plt.title("Impact of Discount Percentage on Rating")
plt.xlabel("Discount Percentage")
plt.ylabel("Average Rating")
# Out:
# Text(0, 0.5, 'Average Rating')

# %%
#Impact of Discount Percentage on Ratings
data['discount_percentage'] = pd.to_numeric(data['discount_percentage'], errors='coerce')
data['rating_count'] = pd.to_numeric(data['rating_count'], errors='coerce')
discount_vs_rating = data.groupby("discount_percentage")["rating_count"].mean().dropna()
sns.histplot(data["discount_percentage"], bins=20, color="red", edgecolor="black", kde=True)
plt.title("Impact of Discount Percentage on Rating Count")
plt.xlabel("Discount Percentage")
plt.ylabel("Average Rating")
# Out:
# Text(0, 0.5, 'Average Rating')

# %%
# Top 10 Rating per Category
data["rating_count"] = pd.to_numeric(data["rating_count"], errors="coerce")
sales_by_category = data.groupby("category")['rating_count'].sum().reset_index()
top_10_ratings = sales_by_category.sort_values(by='rating_count', ascending=False).head(10)

sns.barplot(x="rating_count", y="category", data=top_10_ratings, palette="viridis")
plt.title('Top 10 Categories by Rating Count')
plt.xlabel('Rating Count')
plt.ylabel('Category')
# Out:
# /var/folders/bw/79fdjw551ngb892bf29b24v00000gn/T/ipykernel_10175/865810153.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="rating_count", y="category", data=top_10_ratings, palette="viridis")
# Text(0, 0.5, 'Category')

# %%
# Extract subcategories from the 'category' column
data['subcategory'] = data['category'].str.split('|').str[-1]

# Find the Subcategories with the highest rating
subcategories = data.groupby('subcategory')['rating'].mean().reset_index()
top_subcategories = subcategories.sort_values(by='rating', ascending=False).head(10)

# Plot the results
sns.barplot(x='rating', y='subcategory', data=top_subcategories, palette='viridis')
plt.title('Top 10 Subcategories by Rating')
plt.xlabel('Rating')
plt.ylabel('Subcategory')
# Out:
# /var/folders/bw/79fdjw551ngb892bf29b24v00000gn/T/ipykernel_10175/2968716970.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rating', y='subcategory', data=top_subcategories, palette='viridis')
# Text(0, 0.5, 'Subcategory')

# %%
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# ...

# %%
# Display all subcategories
all_subcategories = data['subcategory'].unique()
print("All Subcategories:")
for subcategory in all_subcategories:
    print(subcategory)
# Display all categories
# Out:
# All Subcategories:
# USBCables
# WirelessUSBAdapters
# HDMICables
# SmartTelevisions
# RemoteControls
# StandardTelevisions
# TVWall&CeilingMounts
# RCACables
# Mounts
# OpticalCables
# Projectors
# Adapters
# SatelliteReceivers
# DVICables
# SpeakerCables
# StreamingClients
# AVReceivers&Amplifiers
# TowerSpeakers
# 3DGlasses
# SmartWatches
# PowerBanks
# Smartphones
# MicroSD
# BasicMobiles
# In-Ear
# AutomobileChargers
# Cradles
# WallChargers
# OTGAdapters
# Tripods
# SelfieSticks
# Stands
# CableConnectionProtectors
# Décor
# ScreenProtectors
# StylusPens
# Bedstand&DeskMounts
# BasicCases
# HandlebarMounts
# On-Ear
# CameraPrivacyCovers
# PhoneCharms
# Shower&WallMounts
# PenDrives
# Mice
# GraphicTablets
# Lapdesks
# NotebookComputerStands
# Keyboards
# Condenser
# DisposableBatteries
# GelInkRollerballPens
# Tape
# Keyboard&MouseSets
# ExternalHardDisks
# VideoCameras
# Tabletop&TravelTripods
# Scientific
# Repeaters&Extenders
# TripodLegs
# InkjetInkCartridges
# DustCovers
# ...

# %%
# Top 10 Highest Rating Products
# Sort the data by rating and select the top 10
top_10_highest_rating = data.sort_values(by='rating', ascending=False).head(10)
# Plot the results
sns.barplot(x='rating', y='product_name', data=top_10_highest_rating, palette='viridis')
plt.title('Top 10 Highest Rated Products')
plt.xlabel('Rating')
plt.ylabel('Product Name')
# Out:
# /var/folders/bw/79fdjw551ngb892bf29b24v00000gn/T/ipykernel_10175/3806108902.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rating', y='product_name', data=top_10_highest_rating, palette='viridis')
# Text(0, 0.5, 'Product Name')

# %%
# Percentage of products been sold using Pie chart
# Calculate the percentage of products sold
products_sold = data['rating_count'].sum()
total_possible_ratings = data['rating_count'].max() * data['rating_count'].count()
percentage_sold = (products_sold / total_possible_ratings) * 100

# Create a pie chart
labels = ['Products Sold', 'Products Not Sold']
sizes = [percentage_sold, 100 - percentage_sold]
colors = ['lightblue', 'lightgray']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular
plt.title('Percentage of Products Sold vs Not Sold')
# Out:
# Text(0.5, 1.0, 'Percentage of Products Sold vs Not Sold')

# %%
# Count occurrences of product names
product_counts = data["product_name"].value_counts()

# Sort in descending order and display top results
print(product_counts.sort_values(ascending=False).head(5))
# Out:
# product_name
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution                                     5
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating                                              4
# Ambrane 2 in 1 Type-C & Micro USB Cable with 60W / 3A Fast Charging, 480 mbps High Data, PD Technology & Quick Charge 3.0, Compatible with All Type-C & Micro USB Devices (ABDC-10, Black)    3
# Pinnaclz Original Combo of 2 Micro USB Fast Charging Cable, USB Charging Cable for Data Transfer Perfect for Android Smart Phones White 1.2 Meter Made in India (Pack of 2)                   3
# Portronics Konnect L POR-1081 Fast Charging 3A Type-C Cable 1.2Meter with Charge & Sync Function for All Type-C Devices (Grey)                                                                3
# ...

# %%
#Top 5 categories based with highest ratings?
top_5_categories = data.groupby('category')['rating'].mean().sort_values(ascending=False).head(5)
print(top_5_categories)
# Plot the results
sns.barplot(x=top_5_categories.values, y=top_5_categories.index, palette='viridis')
plt.title('Top 5 Categories with Highest Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Category')
# Top 5 categories with highest rating count
# Out:
# category
# Computers&Accessories|Tablets                                               4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters    4.5
# Electronics|Cameras&Photography|Accessories|Film                            4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                          4.5
# Name: rating, dtype: float64
# /var/folders/bw/79fdjw551ngb892bf29b24v00000gn/T/ipykernel_10175/2641810179.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_5_categories.values, y=top_5_categories.index, palette='viridis')
# Text(0, 0.5, 'Category')

# %%
#  Top 10 Most Popular Prodcts
top_10_most_popular = data.sort_values(by='rating_count', ascending=False).head(10)
# Plot the results
sns.barplot(x='rating_count', y='product_name', data=top_10_most_popular, palette='viridis')
plt.title('Top 10 Most Popular Products')
plt.xlabel('Rating Count')
plt.ylabel('Product Name')
# Top 10 Most Popular Categories
# Out:
# /var/folders/bw/79fdjw551ngb892bf29b24v00000gn/T/ipykernel_10175/4224047805.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rating_count', y='product_name', data=top_10_most_popular, palette='viridis')
# Text(0, 0.5, 'Product Name')

# %%
# stored the cleaned data in the Data folder
data.to_csv('/Users/smartcookie/Desktop/Data Engineering Files/Projects/Python Projectes/Amazon Sales Data Project/Data/amazon_cleaned.csv', index=False)
# Display the cleaned data
cleaned_data = pd.read_csv('/Users/smartcookie/Desktop/Data Engineering Files/Projects/Python Projectes/Amazon Sales Data Project/Data/amazon_cleaned.csv')
print(cleaned_data.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# ...

# %% [markdown]
# ## 4. Load Data from pandas to MySQL

# %%
# Install the required packages
# %pip install pymysql sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy

# %%
# Create a connection to the MySQL database
import pymysql

from sqlalchemy import create_engine


# URL encode '@' as '%40'
engine = create_engine("mysql+pymysql://root:Madhu%40123.@127.0.0.1:3306/amazon_data")

# %%
import pandas as pd

df = pd.read_sql("SHOW TABLES;", engine)
print(df)
# Out:
#   Tables_in_amazon_data
# 0              products
# 1               reviews
# 2                 users

# %%
df_all = pd.read_csv('/Users/smartcookie/Desktop/Data Engineering Files/Projects/Python Projectes/Amazon Sales Data Project/Data/amazon_cleaned.csv')

# %%
df_all.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'discounted_amount',
#        'subcategory'],
#       dtype='object')

# %%
# Step 2: Create connection
engine = create_engine("mysql+pymysql://root:Madhu%40123.@127.0.0.1:3306/amazon_data")

# %%
# Create Products Table DataFrame
products_df = df_all[['product_id', 'product_name', 'category', 'actual_price',
                      'discounted_price', 'discount_percentage', 'rating']].drop_duplicates()

# %%
# STEP 1: Remove duplicates within the DataFrame
products_df = products_df.drop_duplicates(subset='product_id')

# %%
# STEP 2: Fetch existing product_ids from DB
existing_ids = pd.read_sql("SELECT product_id FROM products", con=engine)

# %%
# STEP 3: Remove already inserted ones
products_df = products_df[~products_df['product_id'].isin(existing_ids['product_id'])]

# %%
# STEP 4: Insert only if not empty
from sqlalchemy.types import String, Text, Float
if not products_df.empty:
    products_df.to_sql('products', con=engine, if_exists='append', index=False, method='multi',
        dtype={
            'product_id': String(50),
            'product_name': Text,
            'category': String(255),
            'actual_price': Float,
            'discounted_price': Float,
            'discount_percentage': Float,
            'rating': Float
        })
    print(f"✅ Inserted {len(products_df)} new products.")
else:
    print("⚠️ No new products to insert.")
# Out:
# ⚠️ No new products to insert.

# %%
# Users Table
users_df = df_all[['user_id', 'user_name']].drop_duplicates()

# %%
from sqlalchemy.types import String

# Fetch existing user_ids from the database
existing_user_ids = pd.read_sql("SELECT user_id FROM users", con=engine)

# Remove duplicates by filtering out rows with user_ids already in the database
users_df = users_df[~users_df['user_id'].isin(existing_user_ids['user_id'])]

if not users_df.empty:
    users_df.to_sql('users', con=engine, if_exists='append', index=False, method='multi',
        dtype={
            'user_id': String(50),
            'user_name': String(100)
        })
    print(f"✅ Inserted {len(users_df)} new users.")
else:
    print("⚠️ No new users to insert.")
# Out:
# ⚠️ No new users to insert.

# %%
# Create Reviews Table DataFrame
reviews_df = df_all[['review_id', 'product_id', 'user_id', 'review_title', 'review_content', 'rating_count']].drop_duplicates()

# %%
# STEP 1: Remove duplicates within the DataFrame
reviews_df = reviews_df.drop_duplicates(subset='review_id')

# %%
# STEP 2: Fetch existing review_ids from DB
existing_review_ids = pd.read_sql("SELECT review_id FROM reviews", con=engine)

# %%
# STEP 3: Remove already inserted ones
reviews_df = reviews_df[~reviews_df['review_id'].isin(existing_review_ids['review_id'])]

# %%
# STEP 4: Insert only if not empty
from sqlalchemy.types import String, Text, Integer
if not reviews_df.empty:
    reviews_df.to_sql('reviews', con=engine, if_exists='append', index=False, method='multi',
        dtype={
            'review_id': String(255),
            'product_id': String(255),
            'user_id': String(255),
            'review_title': Text,
            'review_content': Text,
            'rating_count': Integer
        })
    print(f"✅ Inserted {len(reviews_df)} new reviews.")
else:
    print("⚠️ No new reviews to insert.")
# Out:
# ✅ Inserted 1194 new reviews.
